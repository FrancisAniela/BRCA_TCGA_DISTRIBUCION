# %%
import pandas as pd
df =  pd.read_csv("datos/brca_tcga_pan_can_atlas_2018_clinical_data_total.csv", sep='\t')
df.columns
# Out:
# Index(['Study ID', 'Patient ID', 'Sample ID', 'Diagnosis Age',
#        'Neoplasm Disease Stage American Joint Committee on Cancer Code',
#        'American Joint Committee on Cancer Publication Version Type',
#        'Aneuploidy Score', 'Buffa Hypoxia Score', 'Cancer Type',
#        'TCGA PanCanAtlas Cancer Type Acronym', 'Cancer Type Detailed',
#        'Last Communication Contact from Initial Pathologic Diagnosis Date',
#        'Birth from Initial Pathologic Diagnosis Date',
#        'Last Alive Less Initial Pathologic Diagnosis Date Calculated Day Value',
#        'Disease Free (Months)', 'Disease Free Status',
#        'Months of disease-specific survival',
#        'Disease-specific Survival status', 'Ethnicity Category',
#        'Form completion date', 'Fraction Genome Altered',
#        'Genetic Ancestry Label', 'Neoplasm Histologic Grade',
#        'Neoadjuvant Therapy Type Administered Prior To Resection Text',
#        'ICD-10 Classification',
# ...

# %%
df['Diagnosis Age'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['Diagnosis Age'].describe()
# Out:
# count    1084.000000
# mean       58.420664
# std        13.219721
# min        26.000000
# 25%        49.000000
# 50%        58.000000
# 75%        67.000000
# max        90.000000
# Name: Diagnosis Age, dtype: float64

# %%
df['Subtype'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['Subtype'].value_counts()
# Out:
# Subtype
# BRCA_LumA      499
# BRCA_LumB      197
# BRCA_Basal     171
# BRCA_Her2       78
# BRCA_Normal     36
# Name: count, dtype: int64

# %%
df['Neoplasm Disease Stage American Joint Committee on Cancer Code'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['Neoplasm Disease Stage American Joint Committee on Cancer Code'].value_counts()
# Out:
# Neoplasm Disease Stage American Joint Committee on Cancer Code
# STAGE IIA     355
# STAGE IIB     255
# STAGE IIIA    155
# STAGE I        89
# STAGE IA       86
# STAGE IIIC     64
# STAGE IIIB     28
# STAGE IV       19
# STAGE X        14
# STAGE IB        6
# STAGE II        6
# STAGE III       2
# Name: count, dtype: int64

# %%
df['Cancer Type Detailed'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['Cancer Type Detailed'].value_counts()
# Out:
# Cancer Type Detailed
# Breast Invasive Ductal Carcinoma            780
# Breast Invasive Lobular Carcinoma           201
# Breast Invasive Carcinoma (NOS)              77
# Breast Invasive Mixed Mucinous Carcinoma     17
# Metaplastic Breast Cancer                     8
# Invasive Breast Carcinoma                     1
# Name: count, dtype: int64

# %%
#Ganglios linfaticos
df['Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code'].value_counts()
# Out:
# Neoplasm Disease Lymph Node Stage American Joint Committee on Cancer Code
# N0           329
# N1A          164
# N0 (I-)      154
# N1           123
# N2A           64
# N2            55
# N3A           46
# N1MI          36
# N1B           32
# N0 (I+)       28
# N3            26
# NX            20
# N3B            3
# N1C            2
# N3C            1
# N0 (MOL+)      1
# Name: count, dtype: int64

# %%
#Tamano del tumor
df['American Joint Committee on Cancer Tumor Stage Code'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['American Joint Committee on Cancer Tumor Stage Code'].value_counts()
# Out:
# American Joint Committee on Cancer Tumor Stage Code
# T2     626
# T1C    219
# T3     136
# T1      40
# T4B     27
# T1B     16
# T4       9
# TX       3
# T4D      3
# T1A      2
# T2B      1
# T3A      1
# T2A      1
# Name: count, dtype: int64

# %%
#Metastasis a distancias
df['American Joint Committee on Cancer Metastasis Stage Code'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['American Joint Committee on Cancer Metastasis Stage Code'].value_counts()
# Out:
# American Joint Committee on Cancer Metastasis Stage Code
# M0          895
# MX          162
# M1           21
# CM0 (I+)      6
# Name: count, dtype: int64

# %%
#AJCC estadiaje
df['American Joint Committee on Cancer Publication Version Type'].hist(bins=10 , xlabelsize=12 , figsize=(25,5))
df['American Joint Committee on Cancer Publication Version Type'].value_counts()
# Out:
# American Joint Committee on Cancer Publication Version Type
# 6TH    438
# 7TH    413
# 5TH     56
# 4TH     29
# 3RD      8
# Name: count, dtype: int64
